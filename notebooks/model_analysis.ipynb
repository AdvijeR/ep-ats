# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
import sys
sys.path.append('../src')  
from utils import get_predictions, plot_average_predictions

# %%
tickers = ['GOOGL', 'AMZN', 'AAPL', 'PEP', 'JNJ', 'PFE', 'MRK', 'ABBV', 'PG', 'KO',
           'WMT', 'JPM', 'BAC', 'GS', 'V', 'XOM', 'CVX', 'COP', 'BP', 'BA',
           'MMM', 'HON', 'GE', 'T', 'VZ', 'TMUS', 'HSY', 'DUK', 'SO', 'EXC', 'AEP',
           'AMT', 'PLD', 'SPG', 'BHP', 'RIO', 'VALE', 'FCX']
start_date = '2010-01-01'
end_date = '2023-10-23'
sequence_length = 50

# %%
folder_path = "../notebooks/models"
predictions, actuals = get_predictions(tickers, start_date, end_date, sequence_length, folder_path=folder_path)
# Out:
# Processing GOOGL...
# 2024-08-02 06:21:13.421328: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-02 06:21:13.422912: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 22/22 [==============================] - 2s 43ms/step
# Processing AMZN...
# 22/22 [==============================] - 2s 42ms/step
# Processing AAPL...
# 22/22 [==============================] - 1s 42ms/step
# Processing PEP...
# 22/22 [==============================] - 1s 37ms/step
# Processing JNJ...
# 22/22 [==============================] - 2s 43ms/step
# Processing PFE...
# 22/22 [==============================] - 1s 41ms/step
# Processing MRK...
# 22/22 [==============================] - 1s 41ms/step
# Processing ABBV...
# 17/17 [==============================] - 1s 39ms/step
# Processing PG...
# 22/22 [==============================] - 1s 37ms/step
# Processing KO...
# 22/22 [==============================] - 1s 44ms/step
# Processing WMT...
# 22/22 [==============================] - 2s 44ms/step
# Processing JPM...
# 22/22 [==============================] - 1s 42ms/step
# Processing BAC...
# 22/22 [==============================] - 1s 38ms/step
# Processing GS...
# 22/22 [==============================] - 1s 38ms/step
# Processing V...
# 22/22 [==============================] - 2s 43ms/step
# Processing XOM...
# 22/22 [==============================] - 1s 41ms/step
# Processing CVX...
# 22/22 [==============================] - 1s 39ms/step
# Processing COP...
# 22/22 [==============================] - 1s 40ms/step
# Processing BP...
# 22/22 [==============================] - 1s 39ms/step
# Processing BA...
# 22/22 [==============================] - 1s 38ms/step
# Processing MMM...
# 22/22 [==============================] - 1s 36ms/step
# Processing HON...
# 22/22 [==============================] - 1s 38ms/step
# Processing GE...
# 22/22 [==============================] - 1s 40ms/step
# Processing T...
# 22/22 [==============================] - 1s 39ms/step
# Processing VZ...
# 22/22 [==============================] - 1s 36ms/step
# Processing TMUS...
# 22/22 [==============================] - 1s 42ms/step
# Processing HSY...
# 22/22 [==============================] - 1s 42ms/step
# Processing DUK...
# 22/22 [==============================] - 1s 37ms/step
# Processing SO...
# 22/22 [==============================] - 1s 40ms/step
# Processing EXC...
# 22/22 [==============================] - 1s 40ms/step
# Processing AEP...
# 22/22 [==============================] - 1s 40ms/step
# Processing AMT...
# 22/22 [==============================] - 1s 39ms/step
# Processing PLD...
# 22/22 [==============================] - 1s 40ms/step
# Processing SPG...
# 22/22 [==============================] - 1s 44ms/step
# Processing BHP...
# 22/22 [==============================] - 2s 49ms/step
# Processing RIO...
# 22/22 [==============================] - 1s 39ms/step
# Processing VALE...
# 22/22 [==============================] - 1s 37ms/step
# Processing FCX...
# 22/22 [==============================] - 1s 38ms/step

# %%
def calculate_rmse_for_all_tickers(actuals, predictions):
    rmse_values = {}
    for ticker in actuals.keys():
        actual = actuals[ticker]
        pred = predictions[ticker]
        rmse = sqrt(mean_squared_error(actual, pred))
        rmse_values[ticker] = rmse
        print(f"RMSE for {ticker}: {rmse}")
    return rmse_values

rmse_values = calculate_rmse_for_all_tickers(actuals, predictions)
# Out:
# RMSE for GOOGL: 6.369208827506078
# RMSE for AMZN: 4.517207046571497
# RMSE for AAPL: 4.549304100027488
# RMSE for PEP: 3.4755509655436327
# RMSE for JNJ: 2.499816221535639
# RMSE for PFE: 1.1353740748606072
# RMSE for MRK: 3.3363082621462015
# RMSE for ABBV: 5.14465992402884
# RMSE for PG: 3.596347009690101
# RMSE for KO: 0.974429411875687
# RMSE for WMT: 1.4720965678059388
# RMSE for JPM: 3.3172616388138874
# RMSE for BAC: 1.111592706665696
# RMSE for GS: 14.112525826771945
# RMSE for V: 9.846638923917448
# RMSE for XOM: 2.952776497323338
# RMSE for CVX: 4.339464550916077
# RMSE for COP: 3.3652738290238764
# RMSE for BP: 1.174904871634512
# RMSE for BA: 6.826001198504394
# RMSE for MMM: 3.2341432728848956
# RMSE for HON: 10.199916282878528
# RMSE for GE: 1.874804105503896
# RMSE for T: 0.4365616616572116
# RMSE for VZ: 0.8461816926191671
# RMSE for TMUS: 2.8903225224715032
# RMSE for HSY: 9.621222825535199
# RMSE for DUK: 2.2667363014878767
# RMSE for SO: 1.9849606082324311
# RMSE for EXC: 1.1734334572430838
# RMSE for AEP: 1.6998668860361092
# RMSE for AMT: 9.273574354118038
# RMSE for PLD: 3.4911505484756153
# RMSE for SPG: 3.5610293511089295
# RMSE for BHP: 2.1903159386004383
# RMSE for RIO: 2.2571242369202533
# RMSE for VALE: 0.6906036609438997
# RMSE for FCX: 1.7498860883491252

# %%
plot_average_predictions(predictions, actuals)
